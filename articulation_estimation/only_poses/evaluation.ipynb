# %%
# %reload_ext autoreload
# %autoreload 2

import os

# Update to the root of the project
os.chdir("/home/tlips/Documents/cat-ind-fg/") 
print(f"Changed dir to {os.getcwd()}")

# Update to the root path of your rexperiments
root_path = "./experiments/only_poses/"

import pathlib
import pickle
from typing import Any, Dict, List, Optional, Tuple

import articulation_estimation.evaluation.helpers
import articulation_estimation.helpers as helpers

import matplotlib

matplotlib.rcParams["pdf.fonttype"] = 42
matplotlib.rcParams["ps.fonttype"] = 42

import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import numpy as onp
import pandas as pd
from articulation_estimation.evaluation import eval
import articulation_estimation.experiment_files as experiment_files
import matplotlib
import tqdm
import seaborn as sns
# Out:
# Changed dir to /home/tlips/Documents/cat-ind-fg

# %%
def append_experiment(
    data: Dict["str", List],
    experiment_identifier: str,
    experiment_path: str,
    methods: Dict[str, str],
) -> None:
    def append_sample(
        data: Dict["str", List],
        config_loaded: "articulation_estimation.only_poses.config.FullPoseConfig",
        method: str,
        similarity_score: float,
        angle_error: float,
    ) -> None:
        if "motion_type" not in data:
            data["motion_type"] = []
            data["stddev_pos"] = []
            data["stddev_ori"] = []
            data["motion_range"] = []
            data["num_observations"] = []
            data["method"] = []
            data["similarity_score"] = []
            data["angle_error"] = []
        data["motion_type"].append(config_loaded.motion_type.value)
        data["stddev_pos"].append(config_loaded.stddev_pos)
        data["stddev_ori"].append(config_loaded.stddev_ori * 180 / onp.pi)
        data["motion_range"].append(config_loaded.sample_length)
        data["num_observations"].append(config_loaded.observation_amount)
        data["method"].append(method)
        data["similarity_score"].append(similarity_score)
        data["angle_error"].append(angle_error)

    experiment = experiment_files.ExperimentFiles(
        experiment_identifier, root_path=experiment_path, verbose=False
    )
    error_dict = experiment.read_metadata("error_dict")["errors"]
    config_loaded = experiment.read_metadata("config")

    for method, method_key in methods.items():
        # if error_dict[method_key].shape[0] < 50:
        #     print(
        #         f"Too little samples {experiment_identifier = } {error_dict[method_key].shape = }"
        #     )
        #     continue

        for similarity_score, angle_error in error_dict[method_key]:
            append_sample(
                data,
                config_loaded,
                method,
                similarity_score,
                angle_error * 180 / onp.pi,
            )

# %%
data = {}
experiment_identifiers = os.listdir(root_path)
for experiment_identifier in tqdm.tqdm(experiment_identifiers):
    append_experiment(
        data,
        experiment_identifier,
        root_path,
        {"fg": "pred_fg_twist", "sturm": "pred_sturm_original_twist"},
    )

df = pd.DataFrame(data)
df
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 52.58it/s]
#    motion_type  stddev_pos  stddev_ori  motion_range  num_observations method  \
# 0     rotation        0.01   17.188734          0.15                 3     fg
# 1     rotation        0.01   17.188734          0.15                 3     fg
# 2     rotation        0.01   17.188734          0.15                 3     fg
# 3     rotation        0.01   17.188734          0.15                 3     fg
# 4     rotation        0.01   17.188734          0.15                 3     fg
# 5     rotation        0.01   17.188734          0.15                 3     fg
# 6     rotation        0.01   17.188734          0.15                 3     fg
# 7     rotation        0.01   17.188734          0.15                 3     fg
# 8     rotation        0.01   17.188734          0.15                 3     fg
# 9     rotation        0.01   17.188734          0.15                 3     fg
# 10    rotation        0.01   17.188734          0.15                 3     fg
# 11    rotation        0.01   17.188734          0.15                 3     fg
# 12    rotation        0.01   17.188734          0.15                 3     fg
# 13    rotation        0.01   17.188734          0.15                 3     fg
# 14    rotation        0.01   17.188734          0.15                 3     fg
# 15    rotation        0.01   17.188734          0.15                 3     fg
# 16    rotation        0.01   17.188734          0.15                 3     fg
# 17    rotation        0.01   17.188734          0.15                 3     fg
# 18    rotation        0.01   17.188734          0.15                 3     fg
# 19    rotation        0.01   17.188734          0.15                 3     fg
# 20    rotation        0.01   17.188734          0.15                 3  sturm
# 21    rotation        0.01   17.188734          0.15                 3  sturm
# 22    rotation        0.01   17.188734          0.15                 3  sturm
# 23    rotation        0.01   17.188734          0.15                 3  sturm
# 24    rotation        0.01   17.188734          0.15                 3  sturm
# 25    rotation        0.01   17.188734          0.15                 3  sturm
# 26    rotation        0.01   17.188734          0.15                 3  sturm
# 27    rotation        0.01   17.188734          0.15                 3  sturm
# 28    rotation        0.01   17.188734          0.15                 3  sturm
# 29    rotation        0.01   17.188734          0.15                 3  sturm
# 30    rotation        0.01   17.188734          0.15                 3  sturm
# 31    rotation        0.01   17.188734          0.15                 3  sturm
# 32    rotation        0.01   17.188734          0.15                 3  sturm
# 33    rotation        0.01   17.188734          0.15                 3  sturm
# 34    rotation        0.01   17.188734          0.15                 3  sturm
# 35    rotation        0.01   17.188734          0.15                 3  sturm
# 36    rotation        0.01   17.188734          0.15                 3  sturm
# 37    rotation        0.01   17.188734          0.15                 3  sturm
# 38    rotation        0.01   17.188734          0.15                 3  sturm
# 39    rotation        0.01   17.188734          0.15                 3  sturm
#
#     similarity_score  angle_error
# 0           0.312433    71.786463
# 1           0.448988    63.316168
# 2           0.629950    50.944059
# 3           0.687055    46.598938
# 4           0.569544    55.279139
# 5           0.297574    72.688007
# 6           0.763364    40.072006
# 7           0.780591    38.666022
# 8           0.908806    24.642300
# 9           0.382531    67.480773
# 10          0.560891    55.881702
# 11          0.476320    61.553672
# 12          0.726476    43.365380
# 13          0.146063    81.595619
# 14          0.917780    23.384264
# 15          0.526881    58.179353
# 16          0.962721    15.692370
# 17          0.836651    33.207850
# 18          0.204054    78.225788
# 19          0.537194    57.498732
# 20          0.125603    82.779482
# 21          0.266590    74.535676
# 22          0.403980    66.158544
# 23          0.814299    35.453316
# 24          0.728340    43.245172
# 25          0.348646    69.591083
# 26          0.159049    80.844592
# 27          0.490339    60.606645
# 28          0.879695    28.388373
# 29          0.218968    77.347227
# 30          0.554799    56.302755
# 31          0.227573    76.832962
# 32          0.183002    79.434963
# 33          0.167542    80.344984
# 34          0.001205    89.930942
# 35          0.659493    48.691968
# 36          0.505479    59.608973
# 37          0.072023    85.866584
# 38          0.257477    75.078054
# 39          0.515653    58.953951

# %%
marker_styles = {"fg": "o", "sturm": "^"}
# marker_styles = {"fg": "", "sturm": ""}


def quantile_lineplot(
    ax: plt.Axes,
    data: pd.DataFrame,
    x: str,
    y: str,
    hue: str,
    ci: Tuple[int, int],
    err_kws: Dict[str, Any],
    **kw,
) -> None:
    categories = data[hue].unique()
    for category in categories:
        df_cat = data[data[hue] == category]
        grouped = df_cat.groupby([x])

        df_lower = grouped[y].quantile(ci[0] / 100).reset_index()
        df_middle = grouped[y].median().reset_index()
        df_upper = grouped[y].quantile(ci[1] / 100).reset_index()

        ax.fill_between(df_lower[x], df_lower[y], df_upper[y], **err_kws)
        ax.plot(
            df_middle[x],
            df_middle[y],
            label=category,
            marker=marker_styles[category],
            **kw,
        )

    ax.legend()


def lineplot(
    ax: plt.Axes,
    data: pd.DataFrame,
    x: str,
    xlabel: str,
    labels: List[str] = [],
    plot_quantiles: bool = True,
) -> None:
    if plot_quantiles:
        quantile_lineplot(
            ax=ax,
            data=data,
            x=x,
            y="similarity_score",
            hue="method",
            ci=(25, 75),
            err_kws={"alpha": 0.1},
        )
    else:
        sns.lineplot(
            ax=ax,
            data=data,
            x=x,
            y="similarity_score",
            hue="method",
            ci="sd",
            err_kws={"alpha": 0.1},
        )

    legend = ax.legend()
    for text, label in zip(legend.texts, labels):
        text.set_text(label)

    x_min = data[x].min()
    x_max = min(200, data[x].max())
    ax.set_xlim([x_min, x_max])
    ax.set_ylim([0, 1.001])
    ax.set_xlabel(xlabel)
    ax.set_ylabel(None)
    ax.spines["top"].set_visible(False)


def plot_only_poses(
    data: pd.DataFrame, joint_type: str, path: str, save: bool = True
) -> None:
    assert joint_type in ["prismatic", "revolute"]

    sns.set_theme(style="whitegrid")
    plt.rcParams["font.family"] = "Times New Roman"

    fig, axs = plt.subplots(1, 4, figsize=(12, 2.7), dpi=300)
    fig.suptitle(f"{joint_type.capitalize()} Joints", y=0.91)
    fig.supylabel("Tangent Similarity", fontsize="medium", x=0.01, y=0.51)

    motion_type = "translation" if joint_type == "prismatic" else "rotation"
    idx_joint = data["motion_type"] == motion_type
    df = data[idx_joint]

    methods = ["Factor Graph (ours)", "Sturm et al."]
    motion_unit = "m" if joint_type == "prismatic" else "rad"
    lineplot(axs[0], df, x="num_observations", xlabel="# Observations", labels=methods)
    lineplot(
        axs[1],
        df,
        x="motion_range",
        xlabel=f"Motion Range [{motion_unit}]",
        labels=methods,
    )
    lineplot(
        axs[2],
        df,
        x="stddev_pos",
        xlabel="Position Standard Deviation [m]",
        labels=methods,
    )
    lineplot(
        axs[3],
        df,
        x="stddev_ori",
        xlabel="Orientation Standard Deviation [deg]",
        labels=methods,
    )

    plt.tight_layout(pad=0.9)

    fig_path = pathlib.Path(path) / f"only_poses_{joint_type}.pdf"
    if save:
        fig.savefig(fig_path, bbox_inches="tight", pad_inches=0)

# %%
plot_save_path = "only_poses/plots/"
os.makedirs(plot_save_path, exist_ok=True)

plot_only_poses(df, "prismatic", plot_save_path, save=False)
plot_only_poses(df, "revolute", plot_save_path, save=False)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 4
#       1 plot_save_path = "only_poses/plots/"
#       2 os.makedirs(plot_save_path, exist_ok=True)
# ----> 4 plot_only_poses(df, "prismatic", plot_save_path, save=False)
#       5 plot_only_poses(df, "revolute", plot_save_path, save=False)
#
# Cell In[15], line 96, in plot_only_poses(data, joint_type, path, save)
#      94 methods = ["Factor Graph (ours)", "Sturm et al."]
#      95 motion_unit = "m" if joint_type == "prismatic" else "rad"
# ---> 96 lineplot(axs[0], df, x="num_observations", xlabel="# Observations", labels=methods)
#      97 lineplot(
#      98     axs[1],
#      99     df,
#    (...)
#     102     labels=methods,
#     103 )
#     104 lineplot(
#     105     axs[2],
#     106     df,
#    (...)
#     109     labels=methods,
#     110 )
#
# Cell In[15], line 71, in lineplot(ax, data, x, xlabel, labels, plot_quantiles)
#      69 x_min = data[x].min()
#      70 x_max = min(200, data[x].max())
# ---> 71 ax.set_xlim([x_min, x_max])
#      72 ax.set_ylim([0, 1.001])
#      73 ax.set_xlabel(xlabel)
#
# File ~/miniconda3/envs/fg/lib/python3.8/site-packages/matplotlib/axes/_base.py:3526, in _AxesBase.set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3523     right = xmax
#    3525 self._process_unit_info([("x", (left, right))], convert=False)
# -> 3526 left = self._validate_converted_limits(left, self.convert_xunits)
#    3527 right = self._validate_converted_limits(right, self.convert_xunits)
#    3529 if left is None or right is None:
#    3530     # Axes init calls set_xlim(0, 1) before get_xlim() can be called,
#    3531     # so only grab the limits if we really need them.
#
# File ~/miniconda3/envs/fg/lib/python3.8/site-packages/matplotlib/axes/_base.py:3443, in _AxesBase._validate_converted_limits(self, limit, convert)
#    3440 converted_limit = convert(limit)
#    3441 if (isinstance(converted_limit, Real)
#    3442         and not np.isfinite(converted_limit)):
# -> 3443     raise ValueError("Axis limits cannot be NaN or Inf")
#    3444 return converted_limit
#
# ValueError: Axis limits cannot be NaN or Inf
